# %%
import pandas as pd
df1 = pd.read_csv('AMC/AMC_Quarterly_long_term_debt.csv')
df2 = pd.read_csv('CGX/CGX_Quarterly_long_term_debt.csv')
df3 = pd.read_csv('CNK/CNK_Quarterly_long_term_debt.csv')
display(df1,df2,df3)
# Out:
#           Date (Millions of US $)
# 0    6/30/2023            $4,847
# 1    3/31/2023            $4,914
# 2   12/31/2022            $5,174
# 3    9/30/2022            $5,248
# 4    6/30/2022            $5,414
# 5    3/31/2022            $5,562
# 6   12/31/2021            $5,471
# 7    9/30/2021            $5,499
# 8    6/30/2021            $5,550
# 9    3/31/2021            $5,517
# 10  12/31/2020            $5,779
# 11   9/30/2020            $5,888
# 12   6/30/2020            $5,582
# 13   3/31/2020            $5,106
# 14  12/31/2019            $4,823
# 15   9/30/2019            $4,800
# 16   6/30/2019            $4,823
# 17   3/31/2019            $4,855
# 18  12/31/2018            $5,201
# 19   9/30/2018            $5,357
# 20   6/30/2018            $4,739
# 21   3/31/2018            $4,817
# 22   3/10/2012            $4,799
# 23   3/11/2012            $4,872
# 24   3/12/2012            $4,848
# 25   3/13/2012            $4,793
# 26   3/14/2012            $4,355
# ...

# %%
#add columns of the company names to all of them also divide amc stock price it's not accurate on the graph 
#Adding Company names to column
df1['AMC'] = 'AMC Entertainment Holdings, Inc'

df2['CGX'] = 'Cineplex Inc'

df3['CNK'] = 'Cineworld Group plc'

# Save the updated DataFrames to CSV files
df1.to_csv('AMC/AMC_Quarterly_long_term_debt.csv', index=False)
df2.to_csv('CGX/CGX_Quarterly_long_term_debt.csv', index=False)
df3.to_csv('CNK/CNK_Quarterly_long_term_debt.csv', index=False)
display(df1,df2,df3)
# Out:
#           Date (Millions of US $)                              AMC
# 0    6/30/2023            $4,847   AMC Entertainment Holdings, Inc
# 1    3/31/2023            $4,914   AMC Entertainment Holdings, Inc
# 2   12/31/2022            $5,174   AMC Entertainment Holdings, Inc
# 3    9/30/2022            $5,248   AMC Entertainment Holdings, Inc
# 4    6/30/2022            $5,414   AMC Entertainment Holdings, Inc
# 5    3/31/2022            $5,562   AMC Entertainment Holdings, Inc
# 6   12/31/2021            $5,471   AMC Entertainment Holdings, Inc
# 7    9/30/2021            $5,499   AMC Entertainment Holdings, Inc
# 8    6/30/2021            $5,550   AMC Entertainment Holdings, Inc
# 9    3/31/2021            $5,517   AMC Entertainment Holdings, Inc
# 10  12/31/2020            $5,779   AMC Entertainment Holdings, Inc
# 11   9/30/2020            $5,888   AMC Entertainment Holdings, Inc
# 12   6/30/2020            $5,582   AMC Entertainment Holdings, Inc
# ...

# %%
import pandas as pd

# Load the existing data
df1_existing = pd.read_csv('AMC/AMC_Annual_term_debt.csv')
df2_existing = pd.read_csv('CGX/CGX_Annual_term_debt.csv')
df3_existing = pd.read_csv('CNK/CNK_Annual_term_debt.csv')

# Save the new data to replace the existing files
df1.to_csv('AMC/AMC_Quarterly_long_term_debt.csv', index=False)
df2.to_csv('CGX/CGX_Quarterly_long_term_debt.csv', index=False)
df3.to_csv('CNK/CNK_Quarterly_long_term_debt.csv', index=False)
