# %%
import pandas as pd
df1 = pd.read_csv('AMC/AMC_EBITDA_margin.csv')
df2 = pd.read_csv('CGX/CGX_EBITDA_margin.csv')
df3 = pd.read_csv('CNK/CNK_EBITDA_margin.csv')
display(df1,df2,df3)
# Out:
#           Date TTM Revenue TTM EBITDA EBITDA Margin
# 0    6/30/2023      $4.26B    $-0.03B        -0.59%
# 1    3/31/2023      $4.08B    $-0.13B        -3.11%
# 2   12/31/2022      $3.91B    $-0.18B        -4.58%
# 3    9/30/2022      $4.09B    $-0.01B        -0.29%
# 4    6/30/2022      $3.89B    $-0.03B        -0.85%
# 5    3/31/2022      $3.17B    $-0.31B        -9.67%
# 6   12/31/2021      $2.53B    $-0.49B       -19.19%
# 7    9/30/2021      $1.52B    $-1.37B       -90.06%
# 8    6/30/2021      $0.88B    $-1.88B      -214.16%
# 9    3/31/2021      $0.45B    $-2.02B      -447.78%
# 10  12/31/2020      $1.24B    $-3.61B      -290.35%
# 11   9/30/2020      $2.53B    $-2.60B      -102.65%
# 12   6/30/2020      $3.73B    $-1.90B       -50.89%
# 13   3/31/2020      $5.21B    $-1.33B       -25.47%
# 14  12/31/2019      $5.47B     $0.61B        11.22%
# 15   9/30/2019      $5.44B     $0.68B        12.58%
# 16   6/30/2019      $5.34B     $0.66B        12.28%
# ...

# %%
# Add a Company Name Column to df1
df1['AMC'] = 'AMC Entertainment Holdings, Inc'

# Add a Company Name Column to df2
df2['CGX'] = 'Cineplex Inc'

# Add a Company Name Column to df3
df3['CNK'] = 'Cineworld Group plc'

# Save the updated DataFrames to CSV files
df1.to_csv('AMC_Earnings.csv', index=False)
df2.to_csv('CGX_Earnings.csv', index=False)
df3.to_csv('CNK_Earnings.csv', index=False)
display(df1,df2,df3)
# Out:
#           Date TTM Revenue TTM EBITDA EBITDA Margin  \
# 0    6/30/2023      $4.26B    $-0.03B        -0.59%
# 1    3/31/2023      $4.08B    $-0.13B        -3.11%
# 2   12/31/2022      $3.91B    $-0.18B        -4.58%
# 3    9/30/2022      $4.09B    $-0.01B        -0.29%
# 4    6/30/2022      $3.89B    $-0.03B        -0.85%
# 5    3/31/2022      $3.17B    $-0.31B        -9.67%
# 6   12/31/2021      $2.53B    $-0.49B       -19.19%
# 7    9/30/2021      $1.52B    $-1.37B       -90.06%
# 8    6/30/2021      $0.88B    $-1.88B      -214.16%
# 9    3/31/2021      $0.45B    $-2.02B      -447.78%
# 10  12/31/2020      $1.24B    $-3.61B      -290.35%
# 11   9/30/2020      $2.53B    $-2.60B      -102.65%
# 12   6/30/2020      $3.73B    $-1.90B       -50.89%
# 13   3/31/2020      $5.21B    $-1.33B       -25.47%
# 14  12/31/2019      $5.47B     $0.61B        11.22%
# 15   9/30/2019      $5.44B     $0.68B        12.58%
# 16   6/30/2019      $5.34B     $0.66B        12.28%
# ...

# %%
import pandas as pd

# Load the existing data
df1_existing = pd.read_csv('AMC/AMC_EBITDA_margin.csv')
df2_existing = pd.read_csv('CGX/CGX_EBITDA_margin.csv')
df3_existing = pd.read_csv('CNK/CNK_EBITDA_margin.csv')

# Save the new data to replace the existing files
df1.to_csv('AMC/AMC_EBITDA_margin.csv', index=False)
df2.to_csv('CGX/CGX_EBITDA_margin.csv', index=False)
df3.to_csv('CNK/CNK_EBITDA_margin.csv', index=False)
